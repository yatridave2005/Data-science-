# %%
# !pip install streamlit==1.29.0 pyngrok pandas scikit-learn
# Out:
# Requirement already satisfied: streamlit==1.29.0 in /usr/local/lib/python3.12/dist-packages (1.29.0)
# Requirement already satisfied: pyngrok in /usr/local/lib/python3.12/dist-packages (7.5.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: altair<6,>=4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit==1.29.0) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from streamlit==1.29.0) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit==1.29.0) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.12/dist-packages (from streamlit==1.29.0) (8.3.1)
# Requirement already satisfied: importlib-metadata<7,>=1.4 in /usr/local/lib/python3.12/dist-packages (from streamlit==1.29.0) (6.11.0)
# Requirement already satisfied: numpy<2,>=1.19.3 in /usr/local/lib/python3.12/dist-packages (from streamlit==1.29.0) (1.26.4)
# Requirement already satisfied: packaging<24,>=16.8 in /usr/local/lib/python3.12/dist-packages (from streamlit==1.29.0) (23.2)
# Requirement already satisfied: pillow<11,>=7.1.0 in /usr/local/lib/python3.12/dist-packages (from streamlit==1.29.0) (10.4.0)
# Requirement already satisfied: protobuf<5,>=3.20 in /usr/local/lib/python3.12/dist-packages (from streamlit==1.29.0) (4.25.8)
# Requirement already satisfied: pyarrow>=6.0 in /usr/local/lib/python3.12/dist-packages (from streamlit==1.29.0) (18.1.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.3 in /usr/local/lib/python3.12/dist-packages (from streamlit==1.29.0) (2.9.0.post0)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.12/dist-packages (from streamlit==1.29.0) (2.32.4)
# Requirement already satisfied: rich<14,>=10.14.0 in /usr/local/lib/python3.12/dist-packages (from streamlit==1.29.0) (13.9.4)
# Requirement already satisfied: tenacity<9,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from streamlit==1.29.0) (8.5.0)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.12/dist-packages (from streamlit==1.29.0) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from streamlit==1.29.0) (4.15.0)
# Requirement already satisfied: tzlocal<6,>=1.1 in /usr/local/lib/python3.12/dist-packages (from streamlit==1.29.0) (5.3.1)
# Requirement already satisfied: validators<1,>=0.2 in /usr/local/lib/python3.12/dist-packages (from streamlit==1.29.0) (0.35.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.12/dist-packages (from streamlit==1.29.0) (3.1.45)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /usr/local/lib/python3.12/dist-packages (from streamlit==1.29.0) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in /usr/local/lib/python3.12/dist-packages (from streamlit==1.29.0) (6.5.1)
# Requirement already satisfied: watchdog>=2.1.5 in /usr/local/lib/python3.12/dist-packages (from streamlit==1.29.0) (6.0.0)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.12/dist-packages (from pyngrok) (6.0.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.3)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from altair<6,>=4.0->streamlit==1.29.0) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.12/dist-packages (from altair<6,>=4.0->streamlit==1.29.0) (4.25.1)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.12/dist-packages (from altair<6,>=4.0->streamlit==1.29.0) (2.13.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit==1.29.0) (4.0.12)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata<7,>=1.4->streamlit==1.29.0) (3.23.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil<3,>=2.7.3->streamlit==1.29.0) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit==1.29.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit==1.29.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit==1.29.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit==1.29.0) (2025.11.12)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich<14,>=10.14.0->streamlit==1.29.0) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich<14,>=10.14.0->streamlit==1.29.0) (2.19.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit==1.29.0) (5.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->altair<6,>=4.0->streamlit==1.29.0) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit==1.29.0) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit==1.29.0) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit==1.29.0) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit==1.29.0) (0.30.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit==1.29.0) (0.1.2)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# %%
import streamlit as st

# %%
st.set_page_config(page_title="Disease Prediction System")
st.title("Disease Prediction Based on Symptoms")
st.write("Enter symptoms to predict the most likely disease.")
# Out:
# 2025-12-19 14:19:51.618
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /usr/local/lib/python3.12/dist-packages/colab_kernel_launcher.py [ARGUMENTS]

# %%
# !streamlit run app.py &>/content/logs.txt &

# %%
def load_data():
  df = pd.read_csv("Disease_Prediction_Symptoms_1000.csv")
  return df

# %%
data = load_data()
data
# Out:
#      Fever  Cough  Fatigue  Headache  Nausea  Chest_Pain  Thirst  Weight_Loss  \
# 0        1      1        0         1       0           0       1            0
# 1        0      0        0         0       1           0       1            0
# 2        0      0        1         0       0           0       1            1
# 3        1      1        0         0       0           0       0            0
# 4        0      0        1         0       0           0       1            0
# ..     ...    ...      ...       ...     ...         ...     ...          ...
# 995      1      0        1         0       1           0       0            0
# 996      0      0        0         0       1           0       0            0
# 997      0      0        1         0       0           1       0            1
# 998      0      0        1         0       1           0       0            0
# 999      0      1        1         1       1           0       1            0
#
#      Frequent_Urination         Disease
# 0                     0            Cold
# 1                     0  Food Poisoning
# 2                     1        Diabetes
# 3                     0            Cold
# 4                     1       Gastritis
# ..                  ...             ...
# 995                   1       Gastritis
# 996                   1  Food Poisoning
# 997                   1        Diabetes
# 998                   0   Heart Disease
# 999                   1  Food Poisoning
#
# [1000 rows x 10 columns]

# %%
encoder = LabelEncoder()
data['Disease'] = encoder.fit_transform(data['Disease'])
data
# Out:
#      Fever  Cough  Fatigue  Headache  Nausea  Chest_Pain  Thirst  Weight_Loss  \
# 0        1      1        0         1       0           0       1            0
# 1        0      0        0         0       1           0       1            0
# 2        0      0        1         0       0           0       1            1
# 3        1      1        0         0       0           0       0            0
# 4        0      0        1         0       0           0       1            0
# ..     ...    ...      ...       ...     ...         ...     ...          ...
# 995      1      0        1         0       1           0       0            0
# 996      0      0        0         0       1           0       0            0
# 997      0      0        1         0       0           1       0            1
# 998      0      0        1         0       1           0       0            0
# 999      0      1        1         1       1           0       1            0
#
#      Frequent_Urination  Disease
# 0                     0        0
# 1                     0        3
# 2                     1        1
# 3                     0        0
# 4                     1        4
# ..                  ...      ...
# 995                   1        4
# 996                   1        3
# 997                   1        1
# 998                   0        5
# 999                   1        3
#
# [1000 rows x 10 columns]

# %%
x = data.drop('Disease', axis=1)
y = data['Disease']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2,random_state=42)

# %%
model = RandomForestClassifier(n_estimators=600,max_depth=8)
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(max_depth=8, n_estimators=600)

# %%
accuracy = model.score(x_test, y_test)
print("Accuracy: ", accuracy)
# Out:
# Accuracy:  0.45

# %%
st.subheader("🧾 Select Symptoms (Yes / No)")

def user_input():
    fever = st.checkbox("Fever")
    cough = st.checkbox("Cough")
    fatigue = st.checkbox("Fatigue")
    headache = st.checkbox("Headache")
    nausea = st.checkbox("Nausea")
    chest_pain = st.checkbox("Chest Pain")
    thirst = st.checkbox("Excessive Thirst")
    weight_loss = st.checkbox("Weight Loss")
    frequent_urination = st.checkbox("Frequent Urination")

    return [[
        fever, cough, fatigue, headache, nausea,
        chest_pain, thirst, weight_loss, frequent_urination
    ]]

input_data = user_input()

# %%
encoder = LabelEncoder()
if st.button("Predict Disease"):
    prediction = model.predict(input_data)
    disease_name = encoder.inverse_transform(prediction)[0]

    st.success(f"🧠 Predicted Disease: **{disease_name}**")

# %%
st.subheader("Model Performance")
st.write(f"Accuracy: **{accuracy * 100:.2f}%**")

st.caption("This system is for educational purposes only.")
# Out:
# DeltaGenerator()

# %%
from pyngrok import ngrok
import os, threading


ngrok.kill()

def run():
    os.system(
        "streamlit run app.py "
        "--server.port 8501 "
        "--server.address 0.0.0.0 "
        "--server.headless true "
        "--browser.gatherUsageStats false"
    )

threading.Thread(target=run).start()

ngrok.connect(8501)
# Out:
# <NgrokTunnel: "https://unprorogued-valery-resiliently.ngrok-free.dev" -> "http://localhost:8501">
