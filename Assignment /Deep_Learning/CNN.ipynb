# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import os

# %%
mnist = tf.keras.datasets.mnist
(X_train_full, y_train_full), (X_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
print(f"data type of X_train_full: {X_train_full.dtype},\n shape of X_train_full: {X_train_full.shape}")
# Out:
# data type of X_train_full: uint8,
#  shape of X_train_full: (60000, 28, 28)

# %%
X_valid, X_train = X_train_full[:5000] / 255., X_train_full[5000:] / 255.
y_valid, y_train = y_train_full[:5000], y_train_full[5000:]

X_test = X_test / 255

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Reshape data to include the channel dimension (needed for Conv2D)
X_train = X_train.reshape(-1, 28, 28, 1)
X_valid = X_valid.reshape(-1, 28, 28, 1)
X_test = X_test.reshape(-1, 28, 28, 1)

history = model.fit(X_train, y_train, epochs=50,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9998 - loss: 7.2139e-04 - val_accuracy: 0.9916 - val_loss: 0.0848
# Epoch 2/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9995 - loss: 0.0027 - val_accuracy: 0.9910 - val_loss: 0.0813
# Epoch 3/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9992 - loss: 0.0026 - val_accuracy: 0.9912 - val_loss: 0.0768
# Epoch 4/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9993 - loss: 0.0024 - val_accuracy: 0.9918 - val_loss: 0.0852
# Epoch 5/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9996 - loss: 0.0015 - val_accuracy: 0.9914 - val_loss: 0.0759
# Epoch 6/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9996 - loss: 0.0019 - val_accuracy: 0.9916 - val_loss: 0.1061
# Epoch 7/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9993 - loss: 0.0031 - val_accuracy: 0.9912 - val_loss: 0.1190
# Epoch 8/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9996 - loss: 0.0019 - val_accuracy: 0.9912 - val_loss: 0.1072
# Epoch 9/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9993 - loss: 0.0027 - val_accuracy: 0.9900 - val_loss: 0.0927
# Epoch 10/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9997 - loss: 0.0013 - val_accuracy: 0.9910 - val_loss: 0.0996
# Epoch 11/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9997 - loss: 0.0015 - val_accuracy: 0.9916 - val_loss: 0.0791
# Epoch 12/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9994 - loss: 0.0026 - val_accuracy: 0.9922 - val_loss: 0.0859
# Epoch 13/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9997 - loss: 9.7472e-04 - val_accuracy: 0.9916 - val_loss: 0.0918
# Epoch 14/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9999 - loss: 3.4330e-04 - val_accuracy: 0.9922 - val_loss: 0.0902
# Epoch 15/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 1.0000 - loss: 2.2876e-06 - val_accuracy: 0.9922 - val_loss: 0.0884
# Epoch 16/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9993 - loss: 0.0042 - val_accuracy: 0.9926 - val_loss: 0.0841
# Epoch 17/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9997 - loss: 0.0018 - val_accuracy: 0.9920 - val_loss: 0.1008
# Epoch 18/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9998 - loss: 0.0012 - val_accuracy: 0.9920 - val_loss: 0.1098
# Epoch 19/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9993 - loss: 0.0028 - val_accuracy: 0.9910 - val_loss: 0.1006
# Epoch 20/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9995 - loss: 0.0015 - val_accuracy: 0.9928 - val_loss: 0.0944
# Epoch 21/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9995 - loss: 0.0025 - val_accuracy: 0.9922 - val_loss: 0.0931
# Epoch 22/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9998 - loss: 9.3911e-04 - val_accuracy: 0.9916 - val_loss: 0.0995
# Epoch 23/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 1.0000 - loss: 2.3393e-04 - val_accuracy: 0.9932 - val_loss: 0.0799
# Epoch 24/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9997 - loss: 0.0021 - val_accuracy: 0.9908 - val_loss: 0.1216
# Epoch 25/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9992 - loss: 0.0038 - val_accuracy: 0.9914 - val_loss: 0.1110
# Epoch 26/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9995 - loss: 0.0021 - val_accuracy: 0.9904 - val_loss: 0.0844
# Epoch 27/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9997 - loss: 0.0010 - val_accuracy: 0.9904 - val_loss: 0.1170
# Epoch 28/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9996 - loss: 0.0014 - val_accuracy: 0.9896 - val_loss: 0.1123
# Epoch 29/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9995 - loss: 0.0029 - val_accuracy: 0.9908 - val_loss: 0.1250
# Epoch 30/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9994 - loss: 0.0034 - val_accuracy: 0.9922 - val_loss: 0.0953
# Epoch 31/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9995 - loss: 0.0027 - val_accuracy: 0.9928 - val_loss: 0.1044
# Epoch 32/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9997 - loss: 0.0010 - val_accuracy: 0.9920 - val_loss: 0.1030
# Epoch 33/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9994 - loss: 0.0024 - val_accuracy: 0.9908 - val_loss: 0.1112
# Epoch 34/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9997 - loss: 0.0017 - val_accuracy: 0.9914 - val_loss: 0.1057
# Epoch 35/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 1.0000 - loss: 5.1633e-05 - val_accuracy: 0.9928 - val_loss: 0.1166
# Epoch 36/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9996 - loss: 0.0022 - val_accuracy: 0.9912 - val_loss: 0.1273
# Epoch 37/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9995 - loss: 0.0037 - val_accuracy: 0.9920 - val_loss: 0.1082
# Epoch 38/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9997 - loss: 0.0011 - val_accuracy: 0.9896 - val_loss: 0.1679
# Epoch 39/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9995 - loss: 0.0029 - val_accuracy: 0.9908 - val_loss: 0.1500
# Epoch 40/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9996 - loss: 0.0016 - val_accuracy: 0.9882 - val_loss: 0.1682
# Epoch 41/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9996 - loss: 0.0027 - val_accuracy: 0.9908 - val_loss: 0.1349
# Epoch 42/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9997 - loss: 0.0014 - val_accuracy: 0.9902 - val_loss: 0.1491
# Epoch 43/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9997 - loss: 0.0014 - val_accuracy: 0.9906 - val_loss: 0.1307
# Epoch 44/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9997 - loss: 0.0020 - val_accuracy: 0.9920 - val_loss: 0.1481
# Epoch 45/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9997 - loss: 0.0013 - val_accuracy: 0.9908 - val_loss: 0.1463
# Epoch 46/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9995 - loss: 0.0031 - val_accuracy: 0.9924 - val_loss: 0.1245
# Epoch 47/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9996 - loss: 0.0022 - val_accuracy: 0.9914 - val_loss: 0.1594
# Epoch 48/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9997 - loss: 0.0028 - val_accuracy: 0.9884 - val_loss: 0.2099
# Epoch 49/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9997 - loss: 0.0011 - val_accuracy: 0.9914 - val_loss: 0.1630
# Epoch 50/50
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9996 - loss: 0.0022 - val_accuracy: 0.9916 - val_loss: 0.1491

# %%
plt.figure(figsize=(10, 6))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {test_accuracy:.4f}")
print(f"Test Loss: {test_loss:.4f}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9920 - loss: 0.1411
# Test Accuracy: 0.9920
# Test Loss: 0.1411
