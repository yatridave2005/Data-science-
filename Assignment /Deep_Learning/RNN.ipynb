# %%
import tensorflow as tf
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, LSTM, GRU, Dense
import matplotlib.pyplot as plt

# Load the dataset (top 10,000 words)
max_features = 10000
maxlen = 500
print('Loading data...')
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=max_features)

# Pad sequences to ensure uniform input length
x_train = sequence.pad_sequences(x_train, maxlen=maxlen)
x_test = sequence.pad_sequences(x_test, maxlen=maxlen)
print('Data prepared.')
# Out:
# Loading data...
# ...
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Data prepared.

# %%
# a. Build RNN
model_rnn = Sequential([
    Embedding(max_features, 32),
    SimpleRNN(32),
    Dense(1, activation='sigmoid')
])
model_rnn.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])
history_rnn = model_rnn.fit(x_train, y_train, epochs=20, batch_size=128, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 26s 129ms/step - acc: 0.6395 - loss: 0.6197 - val_acc: 0.7524 - val_loss: 0.5065
# Epoch 2/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 11s 70ms/step - acc: 0.8184 - loss: 0.4186 - val_acc: 0.8202 - val_loss: 0.4124
# Epoch 3/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 21s 69ms/step - acc: 0.8586 - loss: 0.3372 - val_acc: 0.8214 - val_loss: 0.3974
# Epoch 4/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 16s 100ms/step - acc: 0.8858 - loss: 0.2844 - val_acc: 0.8468 - val_loss: 0.3633
# Epoch 5/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 20s 126ms/step - acc: 0.9103 - loss: 0.2323 - val_acc: 0.7908 - val_loss: 0.4465
# Epoch 6/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 18s 113ms/step - acc: 0.9295 - loss: 0.1921 - val_acc: 0.8470 - val_loss: 0.3881
# Epoch 7/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 11s 72ms/step - acc: 0.9473 - loss: 0.1461 - val_acc: 0.7720 - val_loss: 0.5402
# Epoch 8/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 10s 65ms/step - acc: 0.9678 - loss: 0.0985 - val_acc: 0.8450 - val_loss: 0.4621
# ...

# %%
# b. Build LSTM
model_lstm = Sequential([
    Embedding(max_features, 32),
    LSTM(32),
    Dense(1, activation='sigmoid')
])
model_lstm.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])
history_lstm = model_lstm.fit(x_train, y_train, epochs=10, batch_size=128, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 8s 25ms/step - acc: 0.6620 - loss: 0.6039 - val_acc: 0.7108 - val_loss: 0.5497
# Epoch 2/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - acc: 0.8261 - loss: 0.4010 - val_acc: 0.7944 - val_loss: 0.4586
# Epoch 3/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - acc: 0.8627 - loss: 0.3380 - val_acc: 0.8674 - val_loss: 0.3274
# Epoch 4/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - acc: 0.8766 - loss: 0.3059 - val_acc: 0.8672 - val_loss: 0.3264
# Epoch 5/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - acc: 0.8937 - loss: 0.2738 - val_acc: 0.8738 - val_loss: 0.3007
# Epoch 6/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - acc: 0.9011 - loss: 0.2545 - val_acc: 0.8744 - val_loss: 0.3004
# Epoch 7/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - acc: 0.9125 - loss: 0.2322 - val_acc: 0.8786 - val_loss: 0.2928
# Epoch 8/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - acc: 0.9168 - loss: 0.2215 - val_acc: 0.8864 - val_loss: 0.3038
# Epoch 9/10
# ...

# %%
# c. Build GRU
model_gru = Sequential([
    Embedding(max_features, 32),
    GRU(32),
    Dense(1, activation='sigmoid')
])
model_gru.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])
history_gru = model_gru.fit(x_train, y_train, epochs=10, batch_size=128, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - acc: 0.6302 - loss: 0.6285 - val_acc: 0.7994 - val_loss: 0.4460
# Epoch 2/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - acc: 0.8169 - loss: 0.4134 - val_acc: 0.8314 - val_loss: 0.3925
# Epoch 3/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - acc: 0.8522 - loss: 0.3467 - val_acc: 0.8578 - val_loss: 0.3435
# Epoch 4/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - acc: 0.8758 - loss: 0.3039 - val_acc: 0.8592 - val_loss: 0.3499
# Epoch 5/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - acc: 0.8852 - loss: 0.2848 - val_acc: 0.8686 - val_loss: 0.3372
# Epoch 6/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - acc: 0.8971 - loss: 0.2631 - val_acc: 0.8488 - val_loss: 0.3682
# Epoch 7/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - acc: 0.9036 - loss: 0.2425 - val_acc: 0.8556 - val_loss: 0.3334
# Epoch 8/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - acc: 0.9040 - loss: 0.2413 - val_acc: 0.8454 - val_loss: 0.3474
# Epoch 9/10
# ...

# %%
# d. Model Selection & Evaluation
results = {
    'RNN': model_rnn.evaluate(x_test, y_test, verbose=0)[1],
    'LSTM': model_lstm.evaluate(x_test, y_test, verbose=0)[1],
    'GRU': model_gru.evaluate(x_test, y_test, verbose=0)[1]
}

print('\nTest Accuracy Comparison:')
for model_name, acc in results.items():
    print(f'{model_name}: {acc:.4f}')

# Plotting performance
plt.bar(results.keys(), results.values())
plt.title('Model Accuracy Comparison')
plt.ylabel('Accuracy')
plt.show()
# Out:
# Test Accuracy Comparison:
# RNN: 0.8134
# LSTM: 0.8631
# GRU: 0.8508
