# %%
import pandas as pd

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("kushagra3204/sentiment-and-emotion-analysis-dataset")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'sentiment-and-emotion-analysis-dataset' dataset.
# Path to dataset files: /kaggle/input/sentiment-and-emotion-analysis-dataset

# %%
import os

# List files in the downloaded path to identify the CSV file
print(os.listdir(path))
# Out:
# ['archive']

# %%
inner_archive_path = os.path.join(path, 'archive')

files_in_archive = os.listdir(inner_archive_path)

csv_file = None
for f in files_in_archive:
    if f.endswith('.csv'):
        csv_file = f
        break

if csv_file:
    full_csv_path = os.path.join(inner_archive_path, csv_file)
    df = pd.read_csv(full_csv_path)
    display(df.head())
else:
    print(f"No CSV file found in {inner_archive_path}. Found files: {files_in_archive}")
# Out:
#                                             sentence emotion
# 0      i just feel really helpless and heavy hearted    fear
# 1  ive enjoyed being able to slouch about relax a...     sad
# 2  i gave up my internship with the dmrg and am f...    fear
# 3                         i dont know i feel so lost     sad
# 4  i am a kindergarten teacher and i am thoroughl...    fear

# %%
import re
def clean_text(text):
    text = text.lower()
    text = re.sub(r'[^a-zA-Z]', ' ', text)
    return text

# %%
X = df['sentence']
y = df['emotion']

X = X.apply(clean_text)

# %%
# Convert text to vectors (TF-IDF)
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(max_features=5000)
X = tfidf.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
model = MultinomialNB()
model.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8036253776435045
